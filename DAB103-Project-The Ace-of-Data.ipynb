# %%
#import lib
import os
import sys
sys.path
import numpy as np
np.__path__
import pandas as pd
pd.__path__
import seaborn as sns #visualisation
sns.__path__
import matplotlib as plt #visualisation
plt.__path__
# importing matplotlib module 
from matplotlib import pyplot as plt 
# %matplotlib inline
sns.set(color_codes=True)

# %%
#Load Dataset
df = pd.read_csv("ITSalarySurveyEU.csv")
df
# Out:
#                Timestamp  Age Gender          City           Position   \
# 0    24/11/2020 11:14:15   26   Male        Munich   Software Engineer
# 1    24/11/2020 11:14:21   29   Male        Berlin   Software Engineer
# 2    24/11/2020 11:15:53   32   Male        Berlin              DevOps
# 3    24/11/2020 11:20:49   34   Male        Berlin    Mobile Developer
# 4    24/11/2020 11:25:03   38   Male        Berlin           Team Lead
# ..                   ...  ...    ...           ...                 ...
# 489  12/01/2021 12:48:23   37   Male        Berlin    Mobile Developer
# 490  16/01/2021 22:23:04   32   Male        Munich   Software Engineer
# 491  18/01/2021 15:05:50   31   Male        Berlin   Backend Developer
# 492  19/01/2021 10:17:58   26   Male  SaarbrÃ¼cken  Frontend Developer
# 493  19/01/2021 12:01:11   26   Male        Berlin              DevOps
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 0                           5                              3          Senior
# 1                          12                              6            Lead
# 2                           5                              1          Senior
# 3                          11                              5            Lead
# 4                          18                              4            Lead
# ..                        ...                            ...             ...
# 489                        15                              5          Senior
# 490                        10                              5            Head
# 491                         9                              5          Senior
# 492                         7                              7          Middle
# 493                         2                              2          Middle
#
#           Technical language  \
# 0                 TypeScript
# 1    Javascript / Typescript
# 2       AWS, GCP, Python,K8s
# 3                     kotlin
# 4                        iOS
# ..                       ...
# 489                  Android
# 490                    Scala
# 491                     Java
# 492               JavaScript
# 493                     yaml
#
#                               Other Technical language  ...   Bonus+Stocks   \
# 0                      Kotlin, Javascript / Typescript  ...      € 5,000.00
# 1                      Javascript / Typescript, Docker  ...    € 120,000.00
# 2        Python, AWS, Google Cloud, Kubernetes, Docker  ...      € 5,000.00
# 3    Kotlin, Javascript / Typescript, AWS, Google C...  ...     € 80,000.00
# 4                                           Swift, AWS  ...      € 4,000.00
# ..                                                 ...  ...             ...
# 489                                             Kotlin  ...      € 1,000.00
# 490  Javascript / Typescript, Java / Scala, SQL, Go...  ...          € -
# 491  Python, Javascript / Typescript, Java / Scala,...  ...     € 72,000.00
# 492  Javascript / Typescript, Docker, HTML, CSS; Ad...  ...     € 40,950.00
# 493  Python, AWS, Kubernetes, Docker, terraform, an...  ...      € 6,500.00
#
#      Annual brutto salary one year ago(Only answer if staying in the same country)   \
# 0                                          € 75,000.00
# 1                                         € 100,000.00
# 2                                          € 76,000.00
# 3                                          € 75,000.00
# 4                                          € 80,000.00
# ..                                                 ...
# 489                                        € 83,000.00
# 490                                        € 80,000.00
# 491                                        € 70,000.00
# 492                                        € 33,800.00
# 493                                        € 40,000.00
#
#       Bonus+Stocks one year ago(Only answer if staying in same country)   \
# 0                                          € 10,000.00
# 1                                         € 100,000.00
# 2                                           € 5,000.00
# 3                                          € 75,000.00
# 4                                           € 2,000.00
# ..                                                 ...
# 489                                         € 3,500.00
# 490                                             € -
# 491                                        € 72,000.00
# 492                                        € 36,400.00
# 493                                             € -
#
#     Vacation Days           Employment status   Contract duration  \
# 0              30          Full-time employee  Unlimited contract
# 1              30  Self-employed (freelancer)  Temporary contract
# 2              30          Full-time employee  Unlimited contract
# 3              28          Full-time employee  Unlimited contract
# 4              28          Full-time employee  Unlimited contract
# ..            ...                         ...                 ...
# 489            29          Full-time employee  Unlimited contract
# 490            24          Full-time employee  Unlimited contract
# 491            26          Full-time employee  Unlimited contract
# 492            27          Full-time employee  Unlimited contract
# 493            30          Full-time employee  Unlimited contract
#
#     Main language  Company size Company type Lost Job
# 0          English       51-100      Product       No
# 1          English     101-1000      Product      Yes
# 2          English        11-50      Startup       No
# 3          English     101-1000      Product       No
# 4          English     101-1000      Product      Yes
# ..             ...          ...          ...      ...
# 489        English     101-1000      Product       No
# 490        English        11-50      Startup       No
# 491        English       51-100      Product      Yes
# 492         German     101-1000      Product       No
# 493        English       51-100      Startup       No
#
# [494 rows x 21 columns]

# %%
# To display the top 5 rows
df.head(5)
# Out:
#              Timestamp  Age Gender    City          Position   \
# 0  24/11/2020 11:14:15   26   Male  Munich  Software Engineer
# 1  24/11/2020 11:14:21   29   Male  Berlin  Software Engineer
# 2  24/11/2020 11:15:53   32   Male  Berlin             DevOps
# 3  24/11/2020 11:20:49   34   Male  Berlin   Mobile Developer
# 4  24/11/2020 11:25:03   38   Male  Berlin          Team Lead
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                        12                              6            Lead
# 2                         5                              1          Senior
# 3                        11                              5            Lead
# 4                        18                              4            Lead
#
#         Technical language                           Other Technical language  \
# 0               TypeScript                    Kotlin, Javascript / Typescript
# 1  Javascript / Typescript                    Javascript / Typescript, Docker
# 2     AWS, GCP, Python,K8s      Python, AWS, Google Cloud, Kubernetes, Docker
# 3                   kotlin  Kotlin, Javascript / Typescript, AWS, Google C...
# 4                      iOS                                         Swift, AWS
#
#    ...   Bonus+Stocks   \
# 0  ...      € 5,000.00
# 1  ...    € 120,000.00
# 2  ...      € 5,000.00
# 3  ...     € 80,000.00
# 4  ...      € 4,000.00
#
#    Annual brutto salary one year ago(Only answer if staying in the same country)   \
# 0                                        € 75,000.00
# 1                                       € 100,000.00
# 2                                        € 76,000.00
# 3                                        € 75,000.00
# 4                                        € 80,000.00
#
#     Bonus+Stocks one year ago(Only answer if staying in same country)   \
# 0                                        € 10,000.00
# 1                                       € 100,000.00
# 2                                         € 5,000.00
# 3                                        € 75,000.00
# 4                                         € 2,000.00
#
#   Vacation Days           Employment status   Contract duration  \
# 0            30          Full-time employee  Unlimited contract
# 1            30  Self-employed (freelancer)  Temporary contract
# 2            30          Full-time employee  Unlimited contract
# 3            28          Full-time employee  Unlimited contract
# 4            28          Full-time employee  Unlimited contract
#
#   Main language  Company size Company type Lost Job
# 0        English       51-100      Product       No
# 1        English     101-1000      Product      Yes
# 2        English        11-50      Startup       No
# 3        English     101-1000      Product       No
# 4        English     101-1000      Product      Yes
#
# [5 rows x 21 columns]

# %%
# To display the bottom 5 rows
df.tail(5)
# Out:
#                Timestamp  Age Gender          City           Position   \
# 489  12/01/2021 12:48:23   37   Male        Berlin    Mobile Developer
# 490  16/01/2021 22:23:04   32   Male        Munich   Software Engineer
# 491  18/01/2021 15:05:50   31   Male        Berlin   Backend Developer
# 492  19/01/2021 10:17:58   26   Male  SaarbrÃ¼cken  Frontend Developer
# 493  19/01/2021 12:01:11   26   Male        Berlin              DevOps
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 489                        15                              5          Senior
# 490                        10                              5            Head
# 491                         9                              5          Senior
# 492                         7                              7          Middle
# 493                         2                              2          Middle
#
#     Technical language                           Other Technical language  \
# 489            Android                                             Kotlin
# 490              Scala  Javascript / Typescript, Java / Scala, SQL, Go...
# 491               Java  Python, Javascript / Typescript, Java / Scala,...
# 492         JavaScript  Javascript / Typescript, Docker, HTML, CSS; Ad...
# 493               yaml  Python, AWS, Kubernetes, Docker, terraform, an...
#
#      ...   Bonus+Stocks   \
# 489  ...      € 1,000.00
# 490  ...          € -
# 491  ...     € 72,000.00
# 492  ...     € 40,950.00
# 493  ...      € 6,500.00
#
#      Annual brutto salary one year ago(Only answer if staying in the same country)   \
# 489                                        € 83,000.00
# 490                                        € 80,000.00
# 491                                        € 70,000.00
# 492                                        € 33,800.00
# 493                                        € 40,000.00
#
#       Bonus+Stocks one year ago(Only answer if staying in same country)   \
# 489                                         € 3,500.00
# 490                                             € -
# 491                                        € 72,000.00
# 492                                        € 36,400.00
# 493                                             € -
#
#     Vacation Days   Employment status   Contract duration Main language   \
# 489            29  Full-time employee  Unlimited contract        English
# 490            24  Full-time employee  Unlimited contract        English
# 491            26  Full-time employee  Unlimited contract        English
# 492            27  Full-time employee  Unlimited contract         German
# 493            30  Full-time employee  Unlimited contract        English
#
#     Company size Company type Lost Job
# 489     101-1000      Product       No
# 490        11-50      Startup       No
# 491       51-100      Product      Yes
# 492     101-1000      Product       No
# 493       51-100      Startup       No
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 494 entries, 0 to 493
# Data columns (total 21 columns):
#  #   Column                                                                           Non-Null Count  Dtype
# ---  ------                                                                           --------------  -----
#  0   Timestamp                                                                        494 non-null    object
#  1   Age                                                                              494 non-null    int64
#  2   Gender                                                                           494 non-null    object
#  3   City                                                                             494 non-null    object
#  4   Position                                                                         494 non-null    object
#  5   Total years of experience                                                        494 non-null    object
#  6   Years of experience in Germany                                                   494 non-null    object
#  7   Seniority level                                                                  494 non-null    object
#  8   Technical language                                                               494 non-null    object
#  9   Other Technical language                                                         494 non-null    object
#  10   Yearly brutto salary                                                            494 non-null    object
#  11    Bonus+Stocks                                                                   492 non-null    object
#  12   Annual brutto salary one year ago(Only answer if staying in the same country)   493 non-null    object
#  13    Bonus+Stocks one year ago(Only answer if staying in same country)              491 non-null    object
#  14  Vacation Days                                                                    494 non-null    object
#  15  Employment status                                                                494 non-null    object
#  16  Contract duration                                                                494 non-null    object
#  17  Main language                                                                    494 non-null    object
#  18  Company size                                                                     494 non-null    object
#  19  Company type                                                                     494 non-null    object
#  20  Lost Job                                                                         494 non-null    object
# dtypes: int64(1), object(20)
# memory usage: 81.2+ KB

# %%
df.describe()
# Out:
#               Age
# count  494.000000
# mean    32.925101
# std      5.348737
# min     22.000000
# 25%     29.000000
# 50%     33.000000
# 75%     36.000000
# max     56.000000

# %%
#Shape of the data
print(f"Rows : {df.shape[0]}")
print(f"Column : {df.shape[1]}")
# Out:
# Rows : 494
# Column : 21

# %%
#Column Names
print(f"\nAttributes:\n {df.columns.tolist()}")
# Out:
# Attributes:
#  ['Timestamp', 'Age', 'Gender', 'City', 'Position ', 'Total years of experience', 'Years of experience in Germany', 'Seniority level', 'Technical language', 'Other Technical language', ' Yearly brutto salary   ', '  Bonus+Stocks ', ' Annual brutto salary one year ago(Only answer if staying in the same country) ', '  Bonus+Stocks one year ago(Only answer if staying in same country) ', 'Vacation Days', 'Employment status', 'Contract duration', 'Main language ', 'Company size', 'Company type', 'Lost Job']

# %%
#Percentage of missing values
print('Percentage of missing values : \n\n', (100*df.isnull().sum()/df.shape[0]).round(2))
# Out:
# Percentage of missing values :
#
#  Timestamp                                                                          0.00
# Age                                                                                0.00
# Gender                                                                             0.00
# City                                                                               0.00
# Position                                                                           0.00
# Total years of experience                                                          0.00
# Years of experience in Germany                                                     0.00
# Seniority level                                                                    0.00
# Technical language                                                                 0.00
# Other Technical language                                                           0.00
#  Yearly brutto salary                                                              0.00
#   Bonus+Stocks                                                                     0.40
#  Annual brutto salary one year ago(Only answer if staying in the same country)     0.20
#   Bonus+Stocks one year ago(Only answer if staying in same country)                0.61
# Vacation Days                                                                      0.00
# Employment status                                                                  0.00
# Contract duration                                                                  0.00
# Main language                                                                      0.00
# Company size                                                                       0.00
# Company type                                                                       0.00
# Lost Job                                                                           0.00
# dtype: float64

# %%
#Unique Values per column
print('Unique values per column :\n\n',df.nunique())
# Out:
# Unique values per column :
#
#  Timestamp                                                                          494
# Age                                                                                 31
# Gender                                                                               3
# City                                                                                68
# Position                                                                            72
# Total years of experience                                                           39
# Years of experience in Germany                                                      28
# Seniority level                                                                     10
# Technical language                                                                 135
# Other Technical language                                                           317
#  Yearly brutto salary                                                              125
#   Bonus+Stocks                                                                     107
#  Annual brutto salary one year ago(Only answer if staying in the same country)     117
#   Bonus+Stocks one year ago(Only answer if staying in same country)                109
# Vacation Days                                                                       30
# Employment status                                                                    5
# Contract duration                                                                    3
# Main language                                                                       10
# Company size                                                                         5
# Company type                                                                        33
# Lost Job                                                                             4
# dtype: int64

# %%
#Check for Duplicates
print(f'Percentage of duplicate records: {100-(100*df.drop_duplicates().shape[0]/df.shape[0])}')
# Out:
# Percentage of duplicate records: 0.0

# %%
# Age of survey participants distribution
fig, (ax_box,ax_hist) = plt.subplots(2,sharex=True,figsize=(15,8))

sns.boxplot(data=df,x='Age',ax=ax_box)
sns.histplot(data=df,x='Age',kde=True,ax=ax_hist)
plt.title("Age of survey participants distribution",fontsize=20)
plt.xticks(fontsize=13,rotation=90)
plt.xlabel("Different Age Participants",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Frequencies",fontsize=14)
plt.show()

# %%
# Using count plot
plt.figure(figsize=(15,8))
ax = sns.countplot(data=df,x='Gender')
plt.xticks(fontsize=13,rotation=90)
plt.xlabel("Gender",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Frequency",fontsize=14)
plt.title("Gender Participants",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.barplot(data=df['City'].value_counts().head(10).reset_index(),
        y='index',x='City')
plt.xticks(fontsize=13)
plt.xlabel("Frequency",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("City",fontsize=14)
plt.title("Total Survey participants in different cities",fontsize=20)
plt.show()

# %%
# Top 5 City on the survey 
plt.figure(figsize=(15,8))

df['City'].value_counts().iloc[:5].plot.pie(autopct="%1.2f%%",fontsize=13,startangle=90,labels=['']*5,
cmap='Set2',explode=[0.05] * 5,pctdistance=1.2)
plt.ylabel("")
plt.legend(loc='upper left',labels=df['City'].value_counts().iloc[:5].index)
plt.title("Top Five City On The Survey",fontsize=20)
plt.show()

# %%
# Plotting the Boxplots
plt.figure(figsize=(12,8))
sns.boxplot(x='Gender',y='Age',data=df,palette='Pastel2')
plt.xticks(fontsize=13)
plt.xlabel("Gender",fontsize=14)
plt.yticks(fontsize=13)
plt.ylabel("Age",fontsize=14)
plt.title("Survey of Gender by Age",fontsize=20)
plt.show()

# %%
plt.figure(figsize=(18,18))
sns.set_style('whitegrid')
sns.countplot(y='Position ', data=df)
plt.title("Different Job Position",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Different Job Position')

# %%
sns.set_style('whitegrid')
sns.countplot(y='Seniority level', hue='Lost Job', data=df)
plt.title("who lost there Job?",fontsize=20)
plt.xlabel("Total number of people",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
# Out:
# Text(0, 0.5, 'Seniority level')

# %%
sns.set_style('whitegrid')
sns.countplot(y='Seniority level', data=df)
plt.xlabel("Total number of people",fontsize=14)
plt.ylabel("Seniority level",fontsize=14)
plt.title("Seniority level",fontsize=20)
# Out:
# Text(0.5, 1.0, 'Seniority level')
